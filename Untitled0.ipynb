# %% [markdown]
# <a href="https://colab.research.google.com/github/shaharham211/FIDE-Chess-Rating-Guide/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas


import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# FIDE Chess Rating Guide
#
# Chess is one of the oldest and most widely played strategy games in the world, with a history spanning over 1,500 years. Today, the International Chess Federation, known by its French acronym FIDE, serves as the global governing body for competitive chess, maintaining a monthly rating list that tracks the performance of players worldwide. Every month, FIDE publishes an updated list incorporating all rated tournament play from the preceding period, recording each player’s rating title, federation, birth year, and gender. Ratings are calculated using the Elo system, in which players gain or lose points based on performance relative to expectation against opponents, meaning a win against a higher-rated player earns more points than a win against a lower-rated one.

# %%
# !git clone https://github.com/frontiertechinstitute/datasets.git

df = pd.read_csv('/content/datasets/fide_ratings.csv')
df.head()
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 657, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 657 (delta 85), reused 74 (delta 38), pack-reused 483 (from 2)
# Receiving objects: 100% (657/657), 222.02 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (206/206), done.
# Updating files: 100% (209/209), done.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1669/2928945670.py in <cell line: 0>()
#       1 get_ipython().system('git clone https://github.com/frontiertechinstitute/datasets.git')
#       2
# ----> 3 df = pd.read_csv('/content/datasets/fide_ratings.csv')
#       4 df.head()
#
# ...
