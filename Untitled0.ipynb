# %% [markdown]
# <a href="https://colab.research.google.com/github/shaharham211/FIDE-Chess-Rating-Guide/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas


import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# World Cup G.O.A.T.: Ronaldo vs Messi
#
# Through contrasting styles of play, two athletes have spent the last two decades reshaping international soccer. Cristiano Ronaldo and Lionel Messi have fueled an ongoing debate regarding who officially holds the title of the Greatest Of All Time (G.O.A.T.). When it comes to choosing who deserves the title, there are many skills that contribute to a player’s value, beyond counting goals and trophies. This includes their ability to score, create chances and act as a playmaker, that is, a player who sets up scoring opportunities for their teammates, not just for themselves.

# %%
url = ("https://raw.githubusercontent.com/frontiertechinstitute/datasets/refs/heads/main/Ronaldo%20V.s.%20Messi/cleaned_goat_world_cup_data_level1.csv")

data = pd.read_csv(url)

data.head(50)
# Out:
#    tournament_id            tournament_name   match_id  \
# 0        WC-2006  2006 FIFA Men's World Cup  M-2006-21
# 1        WC-2006  2006 FIFA Men's World Cup  M-2006-40
# 2        WC-2006  2006 FIFA Men's World Cup  M-2006-50
# 3        WC-2010  2010 FIFA Men's World Cup  M-2010-04
# 4        WC-2010  2010 FIFA Men's World Cup  M-2010-18
# 5        WC-2010  2010 FIFA Men's World Cup  M-2010-35
# 6        WC-2010  2010 FIFA Men's World Cup  M-2010-52
# 7        WC-2010  2010 FIFA Men's World Cup  M-2010-59
# 8        WC-2014  2014 FIFA Men's World Cup  M-2014-11
# 9        WC-2014  2014 FIFA Men's World Cup  M-2014-27
# 10       WC-2014  2014 FIFA Men's World Cup  M-2014-42
# 11       WC-2014  2014 FIFA Men's World Cup  M-2014-55
# 12       WC-2014  2014 FIFA Men's World Cup  M-2014-59
# 13       WC-2014  2014 FIFA Men's World Cup  M-2014-62
# 14       WC-2014  2014 FIFA Men's World Cup  M-2014-64
# 15       WC-2018  2018 FIFA Men's World Cup  M-2018-06
# ...

# %%
data.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tournament_id    48 non-null     object
#  1   tournament_name  48 non-null     object
#  2   match_id         48 non-null     object
#  3   match_name       48 non-null     object
#  4   match_date       48 non-null     object
#  5   stage_name       48 non-null     object
#  6   group_name       48 non-null     object
#  7   team_name        48 non-null     object
#  8   player_id        48 non-null     object
#  9   given_name       48 non-null     object
#  10  family_name      48 non-null     object
#  11  starter          48 non-null     int64
#  12  substitute       48 non-null     int64
#  13  minutes_played   48 non-null     int64
#  14  total_goals      48 non-null     int64
#  15  open_play_goals  48 non-null     int64
#  16  penalty_goals    48 non-null     int64
# ...

# %%
data.describe()
# Out:
#          starter  substitute  minutes_played  total_goals  open_play_goals  \
# count  48.000000   48.000000       48.000000    48.000000        48.000000
# mean    0.916667    0.083333       85.000000     0.437500         0.291667
# std     0.279310    0.279310       16.758612     0.681246         0.544150
# min     0.000000    0.000000       30.000000     0.000000         0.000000
# 25%     1.000000    0.000000       90.000000     0.000000         0.000000
# 50%     1.000000    0.000000       90.000000     0.000000         0.000000
# 75%     1.000000    0.000000       90.000000     1.000000         0.250000
# max     1.000000    1.000000       90.000000     3.000000         2.000000
#
#        penalty_goals  assists  is_knockout  yellow_cards  red_cards
# count      48.000000     48.0    48.000000     48.000000       48.0
# mean        0.145833      0.0     0.416667      0.125000        0.0
# std         0.356674      0.0     0.498224      0.334219        0.0
# ...

# %%
assists = data['assists'].fillna(data['assists'].mean)

# %%
assists.describe()
# Out:
# count    48.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: assists, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tournament_id    48 non-null     object
#  1   tournament_name  48 non-null     object
#  2   match_id         48 non-null     object
#  3   match_name       48 non-null     object
#  4   match_date       48 non-null     object
#  5   stage_name       48 non-null     object
#  6   group_name       48 non-null     object
#  7   team_name        48 non-null     object
#  8   player_id        48 non-null     object
#  9   given_name       48 non-null     object
#  10  family_name      48 non-null     object
#  11  starter          48 non-null     int64
#  12  substitute       48 non-null     int64
#  13  minutes_played   48 non-null     int64
#  14  total_goals      48 non-null     int64
#  15  open_play_goals  48 non-null     int64
#  16  penalty_goals    48 non-null     int64
# ...

# %%
data.head()
# Out:
#   tournament_id            tournament_name   match_id  \
# 0       WC-2006  2006 FIFA Men's World Cup  M-2006-21
# 1       WC-2006  2006 FIFA Men's World Cup  M-2006-40
# 2       WC-2006  2006 FIFA Men's World Cup  M-2006-50
# 3       WC-2010  2010 FIFA Men's World Cup  M-2010-04
# 4       WC-2010  2010 FIFA Men's World Cup  M-2010-18
#
#                            match_name  match_date   stage_name  \
# 0  Argentina vs Serbia and Montenegro  2006-06-16  group stage
# 1            Netherlands vs Argentina  2006-06-21  group stage
# 2                 Argentina vs Mexico  2006-06-24  round of 16
# 3                Argentina vs Nigeria  2010-06-12  group stage
# 4            Argentina vs South Korea  2010-06-17  group stage
#
#        group_name  team_name player_id given_name  ... starter  substitute  \
# 0         Group C  Argentina   P-14758     Lionel  ...       0           1
# 1         Group C  Argentina   P-14758     Lionel  ...       1           0
# ...

# %%
data.iloc[37, 17] = 1

# %%
data.head(50)
# Out:
#    tournament_id            tournament_name   match_id  \
# 0        WC-2006  2006 FIFA Men's World Cup  M-2006-21
# 1        WC-2006  2006 FIFA Men's World Cup  M-2006-40
# 2        WC-2006  2006 FIFA Men's World Cup  M-2006-50
# 3        WC-2010  2010 FIFA Men's World Cup  M-2010-04
# 4        WC-2010  2010 FIFA Men's World Cup  M-2010-18
# 5        WC-2010  2010 FIFA Men's World Cup  M-2010-35
# 6        WC-2010  2010 FIFA Men's World Cup  M-2010-52
# 7        WC-2010  2010 FIFA Men's World Cup  M-2010-59
# 8        WC-2014  2014 FIFA Men's World Cup  M-2014-11
# 9        WC-2014  2014 FIFA Men's World Cup  M-2014-27
# 10       WC-2014  2014 FIFA Men's World Cup  M-2014-42
# 11       WC-2014  2014 FIFA Men's World Cup  M-2014-55
# 12       WC-2014  2014 FIFA Men's World Cup  M-2014-59
# 13       WC-2014  2014 FIFA Men's World Cup  M-2014-62
# 14       WC-2014  2014 FIFA Men's World Cup  M-2014-64
# 15       WC-2018  2018 FIFA Men's World Cup  M-2018-06
# ...
